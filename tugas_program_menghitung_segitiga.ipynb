# %% [markdown]
# <a href="https://colab.research.google.com/github/hanarosa/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_segitiga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MENGHITUNG BANGUN DATAR LUAS SEGITIGA
#
# Nama Kelompok : Antodonatur
# 1.Adikto
#
# 2.Aulia
#
# 3.Gavin
#
# 4.Ghaisan
#
# 5.Reno
#
# 6.Safira Hana
#
# 7.Evan

# %%
# %%writefile luassegitiga.cpp
# #include <iostream>
# using namespace std;
# int main ()
#  {
#   int a,t,luas;
#   cout<< "program aplikasi menghitung luas segitiga"<<endl;
#   cout<< "masukkan alas segitiga"<<endl;
#   cin>>a;
#   cout<< "masukkan tinggi segitiga"<<endl;
#   cin>>t;
#   luas=0.5*a*t;
#   cout<<"luas segitiga adalah"<<luas<<endl;
# return 0;
# }
# Out:
# Overwriting luassegitiga.cpp

# %%
# !g++ luassegitiga.cpp -o main

# %%
! ./main
# Out:
# program aplikasi menghitung luas segitiga
# masukkan alas segitiga
# 10
# masukkan tinggi segitiga
# 6
# luas segitiga adalah30
